# %% [markdown]
# #importing data to dataframe

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
data = pd.read_csv("E:/Sample - Superstore.csv",encoding='windows-1252')
original_data= pd.read_csv("E:/Sample - Superstore.csv",encoding='windows-1252')

# %% [markdown]
# <h1> Exploring the data</h1>

# %%
data.head(5)
# Out:
#    Row ID        Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 1       2  CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 2       3  CA-2016-138688   6/12/2016   6/16/2016    Second Class    DV-13045
# 3       4  US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
# 4       5  US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City  ...  \
# 0      Claire Gute   Consumer  United States        Henderson  ...
# 1      Claire Gute   Consumer  United States        Henderson  ...
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
#
#   Postal Code  Region       Product ID         Category Sub-Category  \
# ...

# %%
data.shape
# Out:
# (9994, 21)

# %% [markdown]
# <h3>data consisting of 9994 Rows and 21 features (columns)

# %%
data.describe()
# Out:
#             Row ID   Postal Code         Sales     Quantity     Discount  \
# count  9994.000000   9994.000000   9994.000000  9994.000000  9994.000000
# mean   4997.500000  55190.379428    229.858001     3.789574     0.156203
# std    2885.163629  32063.693350    623.245101     2.225110     0.206452
# min       1.000000   1040.000000      0.444000     1.000000     0.000000
# 25%    2499.250000  23223.000000     17.280000     2.000000     0.000000
# 50%    4997.500000  56430.500000     54.490000     3.000000     0.200000
# 75%    7495.750000  90008.000000    209.940000     5.000000     0.200000
# max    9994.000000  99301.000000  22638.480000    14.000000     0.800000
#
#             Profit
# count  9994.000000
# mean     28.656896
# std     234.260108
# min   -6599.978000
# 25%       1.728750
# 50%       8.666500
# 75%      29.364000
# max    8399.976000

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Row ID         9994 non-null   int64
#  1   Order ID       9994 non-null   object
#  2   Order Date     9994 non-null   object
#  3   Ship Date      9994 non-null   object
#  4   Ship Mode      9994 non-null   object
#  5   Customer ID    9994 non-null   object
#  6   Customer Name  9994 non-null   object
#  7   Segment        9994 non-null   object
#  8   Country        9994 non-null   object
#  9   City           9994 non-null   object
#  10  State          9994 non-null   object
#  11  Postal Code    9994 non-null   int64
#  12  Region         9994 non-null   object
#  13  Product ID     9994 non-null   object
#  14  Category       9994 non-null   object
#  15  Sub-Category   9994 non-null   object
#  16  Product Name   9994 non-null   object
# ...

# %% [markdown]
# <h1>No missing data

# %%
data.drop(columns=["Customer Name","Postal Code","Product Name"])
# Out:
#       Row ID        Order ID  Order Date   Ship Date       Ship Mode  \
# 0          1  CA-2016-152156   11/8/2016  11/11/2016    Second Class
# 1          2  CA-2016-152156   11/8/2016  11/11/2016    Second Class
# 2          3  CA-2016-138688   6/12/2016   6/16/2016    Second Class
# 3          4  US-2015-108966  10/11/2015  10/18/2015  Standard Class
# 4          5  US-2015-108966  10/11/2015  10/18/2015  Standard Class
# ...      ...             ...         ...         ...             ...
# 9989    9990  CA-2014-110422   1/21/2014   1/23/2014    Second Class
# 9990    9991  CA-2017-121258   2/26/2017    3/3/2017  Standard Class
# 9991    9992  CA-2017-121258   2/26/2017    3/3/2017  Standard Class
# 9992    9993  CA-2017-121258   2/26/2017    3/3/2017  Standard Class
# 9993    9994  CA-2017-119914    5/4/2017    5/9/2017    Second Class
#
#      Customer ID    Segment        Country             City       State  \
# ...

# %% [markdown]
# now can start explatory analysis

# %%
data.drop_duplicates()
# Out:
#       Row ID        Order ID  Order Date   Ship Date       Ship Mode  \
# 0          1  CA-2016-152156   11/8/2016  11/11/2016    Second Class
# 1          2  CA-2016-152156   11/8/2016  11/11/2016    Second Class
# 2          3  CA-2016-138688   6/12/2016   6/16/2016    Second Class
# 3          4  US-2015-108966  10/11/2015  10/18/2015  Standard Class
# 4          5  US-2015-108966  10/11/2015  10/18/2015  Standard Class
# ...      ...             ...         ...         ...             ...
# 9989    9990  CA-2014-110422   1/21/2014   1/23/2014    Second Class
# 9990    9991  CA-2017-121258   2/26/2017    3/3/2017  Standard Class
# 9991    9992  CA-2017-121258   2/26/2017    3/3/2017  Standard Class
# 9992    9993  CA-2017-121258   2/26/2017    3/3/2017  Standard Class
# 9993    9994  CA-2017-119914    5/4/2017    5/9/2017    Second Class
#
#      Customer ID     Customer Name    Segment        Country             City  \
# ...

# %% [markdown]
# no duplicated data

# %%
numeric_data = data[["Sales","Profit","Quantity","Discount"]]

# %%
cat_data = data.drop(["Sales",	"Quantity",	"Discount",	"Profit"],axis=1)
cat_data
# Out:
#       Row ID        Order ID  Order Date   Ship Date       Ship Mode  \
# 0          1  CA-2016-152156   11/8/2016  11/11/2016    Second Class
# 1          2  CA-2016-152156   11/8/2016  11/11/2016    Second Class
# 2          3  CA-2016-138688   6/12/2016   6/16/2016    Second Class
# 3          4  US-2015-108966  10/11/2015  10/18/2015  Standard Class
# 4          5  US-2015-108966  10/11/2015  10/18/2015  Standard Class
# ...      ...             ...         ...         ...             ...
# 9989    9990  CA-2014-110422   1/21/2014   1/23/2014    Second Class
# 9990    9991  CA-2017-121258   2/26/2017    3/3/2017  Standard Class
# 9991    9992  CA-2017-121258   2/26/2017    3/3/2017  Standard Class
# 9992    9993  CA-2017-121258   2/26/2017    3/3/2017  Standard Class
# 9993    9994  CA-2017-119914    5/4/2017    5/9/2017    Second Class
#
#      Customer ID     Customer Name    Segment        Country             City  \
# ...

# %%
numeric_data.head(5)
# Out:
#       Sales    Profit  Quantity  Discount
# 0  261.9600   41.9136         2      0.00
# 1  731.9400  219.5820         3      0.00
# 2   14.6200    6.8714         2      0.00
# 3  957.5775 -383.0310         5      0.45
# 4   22.3680    2.5164         2      0.20

# %% [markdown]
# <h1>Handling outliers

# %%
from matplotlib import pyplot as plt
import seaborn as sns

# %%
fig, ax = plt.subplots(figsize = (10, 8))

bp = sns.boxplot(data = numeric_data)

bp.set_xticklabels(bp.get_xticklabels(), rotation=90)
# Out:
# [Text(0, 0, 'Sales'),
#  Text(1, 0, 'Profit'),
#  Text(2, 0, 'Quantity'),
#  Text(3, 0, 'Discount')]

# %%
sns.boxplot(numeric_data['Sales'],orient = 'v')
# Out:
# <AxesSubplot: >

# %%
Q1 = numeric_data.quantile(0.25)
Q3 = numeric_data.quantile(0.75)

IQR = Q3 - Q1

print(IQR)
# Out:
# Sales       192.66000
# Profit       27.63525
# Quantity      3.00000
# Discount      0.20000
# dtype: float64

# %%
outliers_removed_data = numeric_data[~ ((numeric_data < (Q1 - 1.5 * IQR)) \
                                     | (numeric_data > (Q3 + 1.5 * IQR))).any(axis=1)]

outliers_removed_data.shape
# Out:
# (7143, 4)

# %% [markdown]
# <h1> now we finish handling outlier

# %%
data=outliers_removed_data.reset_index()

# %%
data.shape
# Out:
# (7143, 5)

# %%
data.drop("index",axis=1)
# Out:
#         Sales   Profit  Quantity  Discount
# 0     261.960  41.9136         2       0.0
# 1      14.620   6.8714         2       0.0
# 2      22.368   2.5164         2       0.2
# 3      48.860  14.1694         7       0.0
# 4       7.280   1.9656         4       0.0
# ...       ...      ...       ...       ...
# 7138  206.100  55.6470         5       0.0
# 7139   25.248   4.1028         3       0.2
# 7140   91.960  15.6332         2       0.0
# 7141  258.576  19.3932         2       0.2
# 7142   29.600  13.3200         4       0.0
#
# [7143 rows x 4 columns]

# %%
data.std()
# Out:
# index       2884.140974
# Sales         92.209665
# Profit        17.187931
# Quantity       1.879085
# Discount       0.106372
# dtype: float64

# %%
data.mean()
# Out:
# index       4985.891222
# Sales         75.707309
# Profit        13.001752
# Quantity       3.407112
# Discount       0.096742
# dtype: float64

# %%
plt.hist(data=data,x="Sales")
# Out:
# (array([4165., 1239.,  635.,  369.,  269.,  136.,  133.,   83.,   57.,
#           57.]),
#  array([  0.99 ,  50.577, 100.164, 149.751, 199.338, 248.925, 298.512,
#         348.099, 397.686, 447.273, 496.86 ]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# <h1>The Sales column is Right Skewed

# %%
sns.distplot(data['Sales'])
# Out:
# C:\Users\NUN\AppData\Local\Temp\ipykernel_6020\1264961287.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data['Sales'])
# <AxesSubplot: xlabel='Sales', ylabel='Density'>

# %%
sns.barplot(x='Sales', y='Category', data=original_data, estimator=np.median)
# Out:
# <AxesSubplot: xlabel='Sales', ylabel='Category'>

# %% [markdown]
# <h1>Most sales in Furnuture and Technology Categories

# %%
data_corr= numeric_data.corr()

# %%
data_corr
# Out:
#              Sales    Profit  Quantity  Discount
# Sales     1.000000  0.479064  0.200795 -0.028190
# Profit    0.479064  1.000000  0.066253 -0.219487
# Quantity  0.200795  0.066253  1.000000  0.008623
# Discount -0.028190 -0.219487  0.008623  1.000000

# %% [markdown]
# theres negative correlation between profit and discount
